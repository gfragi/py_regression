# %%
from importlib_metadata import version
import pandas as pd
from pycaret.regression import *

# %%
df = pd.read_csv('./datasets/paas_data.csv')

# %%
s = setup(data = df, target = 'Price', session_id=123, normalize=True, transformation=True,
          remove_multicollinearity=True, multicollinearity_threshold=0.95,)
# Out:
# <style type="text/css">
# #T_961c6_row9_col1, #T_961c6_row16_col1, #T_961c6_row18_col1, #T_961c6_row20_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_961c6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_961c6_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_961c6_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_961c6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_961c6_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_961c6_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_961c6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_961c6_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_961c6_row1_col1" class="data row1 col1" >Price</td>
#     </tr>
#     <tr>
# ...

# %%
top3 = compare_models(exclude = ['ransac'], n_select = 5)
# Out:
# <style type="text/css">
# #T_233bd th {
#   text-align: left;
# }
# ...

# %%
type(top3)
# Out:
# list

# %%
print(top3)
# Out:
# [ExtraTreesRegressor(n_jobs=-1, random_state=123), LGBMRegressor(random_state=123), GradientBoostingRegressor(random_state=123), RandomForestRegressor(n_jobs=-1, random_state=123), AdaBoostRegressor(random_state=123)]

# %%
lr = create_model('lr', fold = 5)
# Out:
# <style type="text/css">
# #T_aee04_row5_col0, #T_aee04_row5_col1, #T_aee04_row5_col2, #T_aee04_row5_col3, #T_aee04_row5_col4, #T_aee04_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_aee04">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aee04_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_aee04_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_aee04_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_aee04_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_aee04_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_aee04_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
lr = create_model('lr', round = 3)
# Out:
# <style type="text/css">
# #T_f577a_row10_col0, #T_f577a_row10_col1, #T_f577a_row10_col2, #T_f577a_row10_col3, #T_f577a_row10_col4, #T_f577a_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_f577a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f577a_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_f577a_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_f577a_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_f577a_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_f577a_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_f577a_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
plot_model(lr, plot = 'parameter')
# Out:
#                Parameters
# copy_X               True
# fit_intercept        True
# n_jobs                 -1
# normalize      deprecated
# positive            False
